# %%
#Phishing Awareness Training-By EJ
print("=== Phishing Awareness Quiz ===")

score = 0

q1 = input("\n1. A suspicious email asks you to reset your password using a link. Should you click it? (yes/no): ")
if q1.lower() == "no":
    score += 1

q2 = input("\n2. The sender's email ends with '@micr0s0ft-support.com'. Is this real? (yes/no): ")
if q2.lower() == "no":
    score += 1

q3 = input("\n3. The email has grammar mistakes and urgent threats. Is it a phishing sign? (yes/no): ")
if q3.lower() == "yes":
    score += 1

print(f"\nYour Score: {score}/3")
# Out:
# === Phishing Awareness Quiz ===
#
# Your Score: 3/3
